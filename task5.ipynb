# %% [markdown]
# <a href="https://colab.research.google.com/github/Navi-E/NLP_Task1/blob/main/task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
import random
import nltk
from nltk.corpus import stopwords, reuters
from collections import Counter, defaultdict
from nltk import FreqDist, ngrams
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('reuters')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package reuters to /root/nltk_data...
# True

# %%
sents = reuters.sents()
stop_word = set(stopwords.words('english'))
string.punctuation = string.punctuation + '"' + '"' + '-' + '_'
removal_list = list(stop_word) + list(string.punctuation) + ['\t', 'rt']

# %%
unigram = []
bigram = []
trigram = []
tokenized_text = []

# %%
for sentence in sents:
  sentence = list(map(lambda x: x.lower(), sentence))
  for word in sentence:
    if word == '.':
      sentence.remove(word)
    else:
      unigram.append(word)

# %%
tokenized_text.append(word)
bigram.extend(list(ngrams(sentence, 2, pad_left=True, pad_right=True)))
trigram.extend(list(ngrams(sentence, 3, pad_left=True, pad_right=True)))

# %%
def remove_stopwords(x):
  y = []
  for pair in x:
    count = 0

    for word in pair:
      if word in removal_list:
        count = count or 0
      else:
        count = count or 1
    if count == 1:
      y.append(pair)
  return y

# %%
unigram = remove_stopwords(unigram)
bigram = remove_stopwords(bigram)
trigram = remove_stopwords(trigram)

# %%
freq_uni = FreqDist(unigram)
freq_bi = FreqDist(bigram)
freq_tri = FreqDist(trigram)

# %%
d = defaultdict(Counter)
for a, b, c in freq_tri:
  if (a is not None) and (b is not None) and (c is not None):
    d[a, b][c] += freq_tri[a, b, c]

# %%
def pick_word(Counter):
  "Choose a random element"
  return random.choice(list(Counter.elements()))

# %%
prefix = "he", "is"
print("".join(prefix))
s = "".join(prefix)
for i in range(19):
  if prefix in d and d[prefix]:
    suffix = pick_word(d[prefix])
  else:
    # Fallback strategy: if no trigram context, pick a random word from unigrams.
    if freq_uni:
        suffix = pick_word(freq_uni)
    else:
        # If freq_uni is also empty, there's no data to pick from. Break the loop.
        print("No words available for generation.")
        break

  s = s + " " + suffix
  print(s)
  prefix = prefix[1], suffix
# Out:
# heis
# heis domestic
# heis domestic their
# heis domestic their 760
# heis domestic their 760 least
# heis domestic their 760 least drought
# heis domestic their 760 least drought mln
# heis domestic their 760 least drought mln pct
# heis domestic their 760 least drought mln pct the
# heis domestic their 760 least drought mln pct the the
# heis domestic their 760 least drought mln pct the the weekly
# heis domestic their 760 least drought mln pct the the weekly while
# heis domestic their 760 least drought mln pct the the weekly while the
# heis domestic their 760 least drought mln pct the the weekly while the brace
# heis domestic their 760 least drought mln pct the the weekly while the brace by
# heis domestic their 760 least drought mln pct the the weekly while the brace by affiliates
# heis domestic their 760 least drought mln pct the the weekly while the brace by affiliates followed
# ...
